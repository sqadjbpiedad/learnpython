# %% [markdown]
# # DataFrames with Pandas and Polars

# %% [markdown]
# For this part, we will use marimo.
#
# Download the [02_dataframes.py](02_dataframes.py) and [farm_survey_large.csv](farm_survey_large.csv) files.
#
# ```{tip}
# **PRO-TIP**
#
# Make sure you download the files in the same folder as your uv project.
#
# Make sure you **rename the files** to `02_dataframes.py` and `farm_survey_large.csv`.
# ```
#
# Run:
# ```sh
# uv run marimo edit 02_dataframes.py
# ```
